# %% [markdown]
# # Pilot data analyses
#
# This notebook runs back through the pilot data analyses reported in our supplement.
#
# All of the statistical code is the same as reported in 03-primary-analyses so for brevity we call the package to produce the results
#
# All of the figure generation code is the same as reported in 04-primary-figures so for brevity we again call that package

# %%
import numpy as np
import pandas as pd
import src.utils.make_primary_stats as stats
import src.utils.make_primary_figures as figs
import src.utils.dataset_utils as ds_utils
import pingouin as pg

datadir = '/mnt/data/processed/experiment_1'

# %%
data_dict = ds_utils.load_exp_data(datadir)

slider_dict = data_dict["slider_dict"]
model_mat_fits = data_dict["model_mat_fits"]
melted_mmf = data_dict["melted_mmf"]
w1_map_df = data_dict["w1_map_df"]
grouped_stakes = data_dict["grouped_stakes"]
# Out:
# pca_df not found
# dprime_df not found
# w4_map_df not found
# /mnt/src/utils/dataset_utils.py:584: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   good_stakes.groupby(["subid"])["points", "rews_together", "rt_1", "rt_2"]

# %%
# !python -m src.utils.make_primary_stats \
-i /mnt/data/processed/experiment_1 \
-e 1
# Out:
# /mnt/src/utils/dataset_utils.py:584: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   good_stakes.groupby(["subid"])["points", "rews_together", "rt_1", "rt_2"]
# pca_df not found
# dprime_df not found
# w4_map_df not found
# including 93 subjects
# 1 sample ttest from 0 for Visual Co-occurence fit
#                T  dof alternative  ...   cohen-d     BF10     power
# T-test  4.401203   92   two-sided  ...  0.456384  596.932  0.991687
#
# [1 rows x 8 columns]
#
# 1 sample ttest from 0 for Direct reward association fit
#                T  dof alternative  ...   cohen-d       BF10  power
# T-test  6.738391   92   two-sided  ...  0.698739  7.547e+06    1.0
#
# [1 rows x 8 columns]
#
# 1 sample ttest from 0 for Indirect outcome-linked association fit
#                T  dof alternative  ...   cohen-d       BF10  power
# T-test  6.507064   92   two-sided  ...  0.674751  2.734e+06    1.0
#
# ...

# %% [markdown]
# ---
# ## Supplementary figure 1: Model matrix fits for pilot sample

# %%
g, g2 = figs.make_figure_3(model_mat_fits,melted_mmf,False,1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [11], in <cell line: 1>()
# ----> 1 g, g2 = figs.make_figure_3(model_mat_fits,melted_mmf,False,1)
#
# File /mnt/src/utils/make_primary_figures.py:187, in make_figure_3(model_mat_fits, melted_mmf, output_path, exp)
#     185 g.set_xlabels("")
#     186 g.fig.set_facecolor("w")
# --> 187 g.fig.text(0, 1.05, "A", fontsize=fontsize + 10, weight="bold")
#     188 if output_path:
#     189     filename_fig_3a = os.path.join(output_path, "Fig3A.pdf")
#
# File /opt/conda/lib/python3.10/posixpath.py:76, in join(a, *p)
#      71 def join(a, *p):
#      72     """Join two or more pathname components, inserting '/' as needed.
#      73     If any component is an absolute path, all previous path components
#      74     will be discarded.  An empty last part will result in a path that
#      75     ends with a separator."""
# ...

# %% [markdown]
# ---
#
# ## Supplementary Figure 2: Correlations of model matrix fits with points earned and the model-based control parameter

# %%
g = figs.make_figure_5(model_mat_fits, grouped_stakes, w1_map_df, False, 1)
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/regression.py:592: UserWarning: sharey is deprecated from the `lmplot` function signature. Please update your code to pass it using `facet_kws`.
#   warnings.warn(msg, UserWarning)
# /opt/conda/lib/python3.10/site-packages/seaborn/axisgrid.py:88: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   self._figure.tight_layout(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/seaborn/axisgrid.py:88: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   self._figure.tight_layout(*args, **kwargs)
# /opt/conda/lib/python3.10/site-packages/seaborn/axisgrid.py:88: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   self._figure.tight_layout(*args, **kwargs)
# ...
